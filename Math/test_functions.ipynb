# %%
import numpy as np
import matplotlib.pyplot as plt
from loss_functions import entropy, cross_entropy

# %%
x = np.linspace(0.0001,10,100)
y = np.log(x)
e = entropy(x)

# %%
plt.text(0, 0, "O")
plt.plot(x, y, label="log")
plt.xlim(-1, 10)
# plt.ylim(-1, 10)
plt.legend()
plt.grid()

# %%
x = np.linspace(0,1,1000)
e = entropy(x) # not defined on 0 and 1, defined on open interval (0, 1)
plt.text(0, 0, "O")
plt.plot(x, e, label="entropy")
plt.xlim(0, 1)
# plt.ylim(-1, 10)
plt.legend()
plt.grid()

# %%
e[0]
# Out:
# nan

# %%
e[-1]
# Out:
# nan

# %%
entropy(0.5)
# Out:
# 0.6931471805599453

# %%
logits = [0.1, 0.8, 0.1]
y_true = [0, 1, 0]
cross_entropy(logits, y_true)
# Out:
# 0.0
