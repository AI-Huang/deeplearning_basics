# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
# @Date    : Jun-26-21 00:07
# @Author  : Kan HUANG (kan.huang@connect.ust.hk)

import numpy as np
from sklearn import datasets
import matplotlib.pyplot as plt

# %% [markdown]
# ### Moons dataset

# %%
batch_size = 1000
noisy_moons = datasets.make_moons(n_samples=batch_size, noise=None)
X, y = noisy_moons[0].astype(np.float32), noisy_moons[1].astype(np.float32)

# %%
X.shape
# Out:
# (1000, 2)

# %%
plt.figure(figsize=(5, 5))
plt.scatter(X[:, 0], X[:, 1])
plt.xlim(-2, 3)
plt.ylim(-2, 3)
# Out:
# (-2.0, 3.0)
